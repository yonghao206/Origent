# %%
import pandas as pd
path = './output'
df = pd.read_csv(path+'/test_predicted_value_full_three_models.csv')
df.head()
# Out:
#     pid      t  month  true   mod1_XGB   mod2_LGB   mod3_DNN  mod4_Ensemble
# 0  2492    0.0      0  36.0  36.288698  36.015222  35.453050      36.041047
# 1  2492   34.0      1  36.0  35.775760  35.593268  34.272667      35.515956
# 2  2492   96.0      3  36.0  34.034878  33.606211  32.110603      33.585250
# 3  2492  187.0      6  34.0  30.639089  30.020625  29.317804      30.135882
# 4  2492  280.0      9  33.0  28.198960  27.986886  27.194132      27.971233

# %%
import package_gu.pm as pm
# function1: descriptive statistics
# input: the dataset
pm.binned_prediction_summary(df)
# Out:
#               t     month      true  mod1_XGB  mod2_LGB  mod3_DNN  \
# count  1538.000  1538.000  1538.000  1538.000  1538.000  1538.000
# mean    119.433     3.666    34.432    35.001    35.001    34.535
# std     125.724     4.119     8.574     6.172     6.304     6.895
# min       0.000     0.000     4.000    15.980    17.076    17.710
# 25%       8.000     0.000    29.000    31.154    30.648    29.407
# 50%      86.000     2.000    36.000    35.676    35.688    34.553
# 75%     196.000     6.000    41.000    39.846    40.068    39.573
# max     456.000    15.000    48.000    45.963    45.468    51.534
#
#        mod4_Ensemble
# count       1538.000
# mean          34.955
# std            6.301
# min           16.997
# 25%           30.636
# 50%           35.556
# 75%           39.973
# max           46.216

# %%
# function2: histogram of a column. 
# input: a column name of data
pm.histogram(df, 'true')

# %%
# function4 plot predicted VS observed; plot residual VS observed
# input: dataset
pm.draw_scatter(df)

# %%
# function4 plot predicted VS observed; plot residual VS observed
# input: dataset
pm.draw_scatter(df, 't', 0, 366)

# %%
# function6 and 7 compare the perform of models with filtered feature
# input: (dataset, filter_feature, lowerboundary, upperboundary)
q1 = pm.prediction_summary(df)
q1
# Out:
#            mod1_XGB  mod2_LGB  mod3_DNN  mod4_Ensemble
# R^2           0.709     0.713     0.716          0.717
# RMSE          4.625     4.595     4.565          4.563
# Slope         1.188     1.163     1.054          1.167
# Intercept    -7.158    -6.282    -1.967         -6.359
# Skewness     -0.497    -0.456    -0.044         -0.426

# %%
q2 = pm.prediction_summary(df, 't', 0, 366)
q2
# Out:
#            mod1_XGB  mod2_LGB  mod3_DNN  mod4_Ensemble
# R^2           0.749     0.754     0.755          0.757
# RMSE          4.163     4.123     4.112          4.091
# Slope         1.210     1.182     1.053          1.184
# Intercept    -8.052    -7.067    -1.971         -7.091
# Skewness     -0.557    -0.514    -0.079         -0.482

# %%
q3 = pm.prediction_summary(df, 'month', 0,40)
q3
# Out:
#            mod1_XGB  mod2_LGB  mod3_DNN  mod4_Ensemble
# R^2           0.709     0.713     0.716          0.717
# RMSE          4.625     4.595     4.565          4.563
# Slope         1.188     1.163     1.054          1.167
# Intercept    -7.158    -6.282    -1.967         -6.359
# Skewness     -0.497    -0.456    -0.044         -0.426

# %%
# function3: boxplot of predicted value for every model
# input: (dataset, filtered feature, lower, upper)
pm.draw_box(df, 'month', 1, 10)
# Out:
# D:\bigdata\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
# function5 MPE for filtered feature.
# input: (dataset, filtered feature, lowerboundary, upperboundary, model_name in dataset)
pm.MPE_histogram(df, 'month', 1, 12, 'mod4_Ensemble')
